# %%
import os 
proj_dir = os.path.dirname(os.getcwd())
os.chdir(proj_dir)
from flow_analysis import Participant_Flow, Flow_Coordinates

# %%
par_num = 1
par = Participant_Flow(par_num)

# %%
par.flow.plot_pos("2D", add_labels=True)
par.flow.plot_pos("3D", add_labels=True)

# %%
par.flow.plot_pos("2D", add_labels=False)
par.flow.plot_pos("3D", add_labels=False)
par.flow.plot_pos("3D", add_labels=False, view="left")
par.flow.plot_pos("3D", add_labels=False, view="right")
par.flow.plot_pos("3D", add_labels=False, view="anterior")
par.flow.plot_pos("3D", add_labels=False, view="posterior")

# %%
channels = [372, 466, 1992, 2088, 2524, 2606, 4214, 4280]
par.flow.plot_pos("2D", add_labels=True, channels=channels)
par.flow.plot_pos("3D", add_labels=True, channels=channels)
par.flow.plot_pos("3D", add_labels=True, view="left", channels=channels)
par.flow.plot_pos("3D", add_labels=True, view="right", channels=channels)

# %%
print(par.flow.create_source_detector_df("3D", add_missing=True, brain_regions=True, channels=channels, depth=10).to_string(index=False))
# Out:
#  channel_num  measurement_list_index  data_type data_type_index  detector_index  source_index source_label  source_x_pos  source_y_pos  source_z_pos detector_label  detector_x_pos  detector_y_pos  detector_z_pos  midpoint_x_pos  midpoint_y_pos  midpoint_z_pos  midpoint_x_XYZ  midpoint_y_XYZ  midpoint_z_XYZ  midpoint_x_MNI  midpoint_y_MNI  midpoint_z_MNI  AAL_distance        AAL_region  BA_distance            BA_region
#          372                     373      99999             HbO              31             6          S06     59.751930     50.315045     31.836432          D06d0       60.952649       45.127481       40.235482       60.352289       47.721263       36.035957      133.686745      160.237322       76.243141       42.686745       34.237322        4.243141          0.00 Frontal_Inf_Tri_R         0.00           Right-BA46
#          466                     467      99999             HbO              37             7          S07    -59.674647     50.305304     31.784509          D07d0      -65.149905       48.090960       23.695413      -62.412276       49.198132       27.739961       45.791949      161.367331       67.821349      -45.208051       35.367331       -4.178651          0.00 Frontal_Inf_Orb_L         0.00            Left-BA47
#         1992                    1993      99999             HbO             139            24          S24     81.544151    -21.113208     47.244263          D24d0       81.010940      -11.088172       46.085770       81.277546      -16.100690       46.665016      148.668439      111.404675       87.033374       57.668439      -14.595325       15.033374          0.00   Rolandic_Oper_R         0.00           Right-BA40
#         2088                    2089      99999             HbO             145            25          S25    -81.457727    -21.160500     47.233720          D25d0      -79.492188      -25.058638       56.259293      -80.474957      -23.109569       51.746507       32.859750      106.041910       92.191917      -58.140250      -19.958090       20.191917          0.00   SupraMarginal_L         0.00 Left-PrimSensory (1)
#         2524                    2525      99999             HbO             175            30          S30     47.587094    -58.969341     86.131501          D30d0       50.163643      -49.393781       88.221720       48.875369      -54.181561       87.176610      125.469703       82.267526      128.159264       34.469703      -43.732474       56.159264          0.00    Parietal_Inf_R         0.00            Right-BA7
#         2606                    2607      99999             HbO             181            31          S31    -47.641072    -58.910522     86.169569          D31d0      -39.868770      -63.108952       90.824620      -43.754921      -61.009737       88.497095       59.149911       77.043024      129.499771      -31.850089      -48.956976       57.499771          0.00    Parietal_Sup_L         0.00             Left-BA7
#         4214                    4215      99999             HbO             295            50          S50     56.978423    -99.337842    -13.765127          D50d0       52.872790     -103.916370      -21.776315       54.925607     -101.627106      -17.770721      129.801445       45.965103       21.620567       38.801445      -80.034897      -50.379433          3.00 Cerebelum_Crus2_R        30.08  Right-Fusiform (37)
#         4280                    4281      99999             HbO             301            51          S51    -56.993148    -99.328864    -13.652867          D51d0      -64.353876      -92.753542      -15.015656      -60.673512      -96.041203      -14.334261       47.036838       50.239093       25.109136      -43.963162      -75.760907      -46.890864          2.24 Cerebelum_Crus2_L        27.73   Left-Fusiform (37)

# %%
FC = Flow_Coordinates(par.flow.create_source_detector_df("3D", add_missing=True, midpoint_only=True))
FC.plot_coordinates("MNI", 0)
FC.plot_coordinates("MNI", 10)

# %%
flow_atlas = par.flow.load_flow_atlas(depth=10, minimal=True)
flow_atlas
# Out:
#      channel_num  AAL_distance         AAL_region  BA_distance   BA_region
# 0           <NA>         13.04  Frontal_Sup_Orb_R        12.37  Right-BA11
# 1           <NA>         13.04  Frontal_Sup_Orb_R        12.37  Right-BA11
# 2           <NA>         12.37  Frontal_Sup_Orb_R        11.92  Right-BA11
# 3           <NA>         12.37  Frontal_Sup_Orb_R        11.92  Right-BA11
# 4           <NA>          8.66  Frontal_Sup_Orb_R         8.31  Right-BA11
# ..           ...           ...                ...          ...         ...
# 619         4287          2.24  Cerebelum_Crus2_L        26.04   Left-BA19
# 620         4288          0.00  Cerebelum_Crus2_L        22.20   Left-BA19
# 621         4289          0.00  Cerebelum_Crus2_L        22.20   Left-BA19
# 622         4290          0.00  Cerebelum_Crus2_L        22.65   Left-BA19
# 623         4291          0.00  Cerebelum_Crus2_L        22.65   Left-BA19
#
# [624 rows x 5 columns]

# %%
par.flow.load_flow_atlas(depth=10, minimal=True, channels=[0, 1, 2, 3, 4, 5])
# Out:
#     channel_num  AAL_distance         AAL_region  BA_distance  BA_region
# 12            0          9.49  Frontal_Sup_Orb_L        10.30  Left-BA11
# 13            1          9.49  Frontal_Sup_Orb_L        10.30  Left-BA11
# 14            2         13.64  Frontal_Sup_Orb_L        13.93  Left-BA11
# 15            3         13.64  Frontal_Sup_Orb_L        13.93  Left-BA11
# 16            4         14.73  Frontal_Sup_Orb_L        14.63  Left-BA11
# 17            5         14.73  Frontal_Sup_Orb_L        14.63  Left-BA11
