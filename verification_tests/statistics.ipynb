# %%
import os 
proj_dir = os.path.dirname(os.getcwd())
os.chdir(proj_dir)
from flow_analysis import Flow_Results

# %%
FR = Flow_Results()
exp_name = "n_back"
hemo_type = "HbO"
filter_type = "lowpass"

# %%
stats = FR.load_flow_stats(
    exp_name,
    hemo_type=hemo_type,
    filter_type=filter_type,
    corr=False,
    sig_only=True,
    brain_regions=True,
    depth=10,
    print_sig_results=True,
)
print("\nWith Bonferroni correction: \n")
stats = FR.load_flow_stats(
    exp_name,
    hemo_type=hemo_type,
    filter_type=filter_type,
    corr=True,
    sig_only=True,
    brain_regions=True,
    depth=10,
    print_sig_results=True,
)
# Out:
#  channel_num  p_value  F_value  df1  df2  is_sig  AAL_distance          AAL_region  BA_distance              BA_region
#         1900 0.003103 7.148797    2   28    True          0.00       Postcentral_L         0.00     Left-PrimMotor (4)
#         3254 0.004841 6.711299    2   24    True          0.00      Temporal_Inf_L         0.00     Left-Fusiform (37)
#         1468 0.010267 5.488827    2   26    True          0.00 Temporal_Pole_Sup_R         0.00             Right-BA38
#         4062 0.012992 5.325874    2   22    True          8.49   Cerebelum_Crus2_R        26.31 Right-VisualAssoc (18)
#         3686 0.014541 5.159521    2   22    True          4.58           Lingual_R         2.24 Right-VisualAssoc (18)
#         1720 0.014804 4.975601    2   26    True          0.00        Precentral_L         0.00               Left-BA6
#         3256 0.015033 5.025239    2   24    True          0.00      Temporal_Inf_L         0.00     Left-Fusiform (37)
# ...

# %%
FR.plot_stat_results(dim="2D", exp_name=exp_name, hemo_type=hemo_type, filter_type=filter_type, add_labels=True)
FR.plot_stat_results(dim="2D", exp_name=exp_name, hemo_type=hemo_type, filter_type=filter_type, add_labels=True, corr=True)

# %%
FR.plot_stat_results(dim="3D", exp_name=exp_name, hemo_type=hemo_type, filter_type=filter_type)
FR.plot_stat_results(dim="3D", exp_name=exp_name, hemo_type=hemo_type, filter_type=filter_type, corr=True)
